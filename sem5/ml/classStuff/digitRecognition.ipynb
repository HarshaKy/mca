# %% [markdown]
# # Digit Recognition

# %% [markdown]
# # Import Libs and Get Dataset

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test,  y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
plt.imshow(x_train[0], cmap='gray')
# plt.show()

# %% [markdown]
# # Build the Model

# %%
# x_trian[0]
from keras.utils import normalize
x_train = normalize(x_train, axis=1)
x_test = normalize(x_test, axis=1)
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# # Training the Model

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x=x_train, y=y_train, epochs=50)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0141 - accuracy: 0.9953
# Epoch 2/50
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0130 - accuracy: 0.9954
# Epoch 3/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0113 - accuracy: 0.9960
# Epoch 4/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0098 - accuracy: 0.9967
# Epoch 5/50
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.0099 - accuracy: 0.9966
# Epoch 6/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0090 - accuracy: 0.9969
# Epoch 7/50
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0084 - accuracy: 0.9973
# Epoch 8/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0092 - accuracy: 0.9969
# Epoch 9/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0080 - accuracy: 0.9971
# Epoch 10/50
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0086 - accuracy: 0.9971
# Epoch 11/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0071 - accuracy: 0.9977
# Epoch 12/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0075 - accuracy: 0.9973
# Epoch 13/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0068 - accuracy: 0.9978
# Epoch 14/50
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0070 - accuracy: 0.9980
# Epoch 15/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0072 - accuracy: 0.9977
# Epoch 16/50
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0060 - accuracy: 0.9980
# Epoch 17/50
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0054 - accuracy: 0.9984
# Epoch 18/50
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0060 - accuracy: 0.9981
# Epoch 19/50
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0057 - accuracy: 0.9982
# Epoch 20/50
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0075 - accuracy: 0.9978
# Epoch 21/50
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.0050 - accuracy: 0.9985
# Epoch 22/50
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0069 - accuracy: 0.9978
# Epoch 23/50
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0059 - accuracy: 0.9983
# Epoch 24/50
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.0040 - accuracy: 0.9988
# Epoch 25/50
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.0069 - accuracy: 0.9976
# Epoch 26/50
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0036 - accuracy: 0.9988
# Epoch 27/50
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.0045 - accuracy: 0.9985
# Epoch 28/50
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.0064 - accuracy: 0.9980
# Epoch 29/50
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0051 - accuracy: 0.9984
# Epoch 30/50
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0044 - accuracy: 0.9986
# Epoch 31/50
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.0048 - accuracy: 0.9987
# Epoch 32/50
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0059 - accuracy: 0.9983
# Epoch 33/50
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0040 - accuracy: 0.9989
# Epoch 34/50
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0046 - accuracy: 0.9986
# Epoch 35/50
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.0057 - accuracy: 0.9983
# Epoch 36/50
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.0058 - accuracy: 0.9983
# Epoch 37/50
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.0045 - accuracy: 0.9989
# Epoch 38/50
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0053 - accuracy: 0.9987
# Epoch 39/50
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0031 - accuracy: 0.9988
# Epoch 40/50
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0057 - accuracy: 0.9985
# Epoch 41/50
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.0032 - accuracy: 0.9991
# Epoch 42/50
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.0036 - accuracy: 0.9990
# Epoch 43/50
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.0065 - accuracy: 0.9985
# Epoch 44/50
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.0022 - accuracy: 0.9993
# Epoch 45/50
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0054 - accuracy: 0.9986
# Epoch 46/50
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.0039 - accuracy: 0.9987
# Epoch 47/50
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.0047 - accuracy: 0.9988
# Epoch 48/50
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.0042 - accuracy: 0.9988
# Epoch 49/50
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.0053 - accuracy: 0.9985
# Epoch 50/50
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.0040 - accuracy: 0.9991

# %%
loss, test_acc = model.evaluate(x=x_test, y=y_test)
('\n Test Accuracy: ',  test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# ('\n Test Accuracy: ', 0.9784)

# %% [markdown]
# # Making Predictions

# %%
predictions = model.predict([x_test])

# %%
import numpy as np

# %%
print(np.argmax(predictions[1262]))
# Out:
# 2

# %%
plt.imshow(x_test[1262], cmap='gray')
